# %%
import Pkg
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`

# %%
using Plots

# %%
x = [1,2,3,4,5,6]
y = [3,0,3,1,0,1]
plot(x, y, title = "Statistics", xlabel = ["Roll Number"],ylabel = ["Dice Face"], lw = 3)

# %%
x = [1,2,3,4,5,6]
y = [3,0,3,1,0,1]
plot(x,y, seriestype = :scatter, title = "Ratio of Dice Rolls", xlabel = "Roll Number", ylabel = "Dice Face",label = "Numerator")
