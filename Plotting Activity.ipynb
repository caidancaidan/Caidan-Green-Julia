# %%
using Plots

# %%
plot(["Bookstore", "website", "online", "off campus", "rented","ebooks","Didn't buy"], 
    [576, 48, 240, 168, 36, 12, 72], seriestype = :bar, title = "Where books purchased", xlabel = "where boooks bought", ylabel = "how many people bought", label = "books bought")

# %%
X = ["Security", "Maintainence", "Flight Operations", "Flight Operations", "Hazordous Materials","Other"]
Y = [0.43, 0.39, 0.06, 0.03, 0.09,0]
 
P = pie(X,Y)
